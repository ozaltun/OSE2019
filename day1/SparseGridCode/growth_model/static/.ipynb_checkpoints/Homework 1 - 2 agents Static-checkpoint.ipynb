# %%
import os
os.environ["Method"] = "static"
import nonlinear_solver_initial as solver     #solves opt. problems for terminal VF
import nonlinear_solver_iterate as solviter   #solves opt. problems during VFI
import interpolation as interpol              #interface to sparse grid library/terminal VF
import interpolation_iter as interpol_iter    #interface to sparse grid library/iteration
import postprocessing as post                 #computes the L2 and Linfinity error of the model
from parameters import *
import TasmanianSG                            #sparse grid library
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
from mpl_toolkits.mplot3d import Axes3D
from IPython.display import HTML

# %%
def main():
    valnew_dict = dict()
    # terminal value function
    valnew=TasmanianSG.TasmanianSparseGrid()
    if (numstart==0):
        valnew=interpol.sparse_grid(n_agents, iDepth)
        valnew_dict[numstart] = valnew
        valnew.write("valnew_1." + str(numstart) + ".txt") #write file to disk for restart

    # value function during iteration
    else:
        valnew_dict[numstart] = valnew
        valnew.read("valnew_1." + str(numstart) + ".txt")  #write file to disk for restart

    valold=TasmanianSG.TasmanianSparseGrid()
    valold=valnew

    for i in range(numstart, numits):
        valnew=TasmanianSG.TasmanianSparseGrid()
        valnew=interpol_iter.sparse_grid_iter(n_agents, iDepth, valold)
        valold=TasmanianSG.TasmanianSparseGrid()
        valold=valnew
        valnew_dict[i+1] = valnew
        valnew.write("valnew_1." + str(i+1) + ".txt")

    #======================================================================
    print( "===============================================================")
    print( " " )
    print( " Computation of a growth model of dimension ", n_agents ," finished after ", numits, " steps")
    print( " " )
    print( "===============================================================")
    #======================================================================

    # compute errors   
    avg_err=post.ls_error(n_agents, numstart, numits, No_samples)
    
    #======================================================================
    print( "===============================================================")
    print( " ")
    print( " Errors are computed -- see errors.txt")
    print( " ")
    print( "===============================================================")
    #======================================================================
    return valnew_dict

# %%
valnew_dict = main()
errors = np.loadtxt('errors.txt')
# Out:
# ===============================================================
#
# (' Computation of a growth model of dimension ', 2, ' finished after ', 10, ' steps')
#
# ===============================================================
# (1000, 2)
# (1000, 2)
# (1000, 2)
# (1000, 2)
# (1000, 2)
# (1000, 2)
# (1000, 2)
# (1000, 2)
# (1000, 2)
# (1000, 2)
# ===============================================================
#
#  Errors are computed -- see errors.txt
#
# ===============================================================

# %%
valnew_dict[10].plotResponse2D()
# Out:
# <module 'matplotlib.pyplot' from '/software/python-2.7.12-el7-x86_64/lib/python2.7/site-packages/matplotlib/pyplot.pyc'>

# %%
def draw_plots(errors):
    refinement = errors[:,0]
    error_max = errors[:,1]
    error_mean = errors[:,2]
    
    fig, ax = plt.subplots(1, 2, figsize=(10,5))
    ax[0].scatter(refinement, error_max)
    ax[0].set_xlabel('Refinement')
    ax[0].set_ylabel('Max Error')
    
    ax[1].scatter(refinement, error_mean)
    ax[1].set_xlabel('Refinement')
    ax[1].set_ylabel('Mean Error')
    
    return fig, ax

fig, ax = draw_plots(errors)
plt.show()

# %%
def draw_3d_grid(valnew_dict):
    fig = plt.figure()
    ax = Axes3D(fig)
    
    print('fig size: {0} DPI, size in inches {1}'.format(
        fig.get_dpi(), fig.get_size_inches()))

    ax.scatter([],[],[])

    def update(i):
        label = 'refinement {0}'.format(i+1)
        ax.scatter(valnew_dict[i].getPoints()[:,0], valnew_dict[i].getPoints()[:,1],valnew_dict[i].evaluateBatch(valnew_dict[i].getPoints()),color='blue')
        ax.set_title(label)

    anim = FuncAnimation(fig, update, frames=np.arange(0, 16), interval=1000)
    return anim

anim = draw_3d_grid(valnew_dict)
HTML(anim.to_jshtml())
# Out:
# fig size: 72.0 DPI, size in inches [6. 4.]
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_imgb8f0ea935fd54542981f4bf2aaf225fc">
#     <br>
#     <input id="_anim_sliderb8f0ea935fd54542981f4bf2aaf225fc" type="range" style="width:350px"
#            name="points" min="0" max="1" step="1" value="0"
#            onchange="animb8f0ea935fd54542981f4bf2aaf225fc.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="animb8f0ea935fd54542981f4bf2aaf225fc.slower()"><i class="fa fa-minus"></i></button>
#     <button onclick="animb8f0ea935fd54542981f4bf2aaf225fc.first_frame()"><i class="fa fa-fast-backward">
#         </i></button>
#     <button onclick="animb8f0ea935fd54542981f4bf2aaf225fc.previous_frame()">
#         <i class="fa fa-step-backward"></i></button>
#     <button onclick="animb8f0ea935fd54542981f4bf2aaf225fc.reverse_animation()">
#         <i class="fa fa-play fa-flip-horizontal"></i></button>
#     <button onclick="animb8f0ea935fd54542981f4bf2aaf225fc.pause_animation()"><i class="fa fa-pause">
#         </i></button>
#     <button onclick="animb8f0ea935fd54542981f4bf2aaf225fc.play_animation()"><i class="fa fa-play"></i>
#         </button>
#     <button onclick="animb8f0ea935fd54542981f4bf2aaf225fc.next_frame()"><i class="fa fa-step-forward">
#         </i></button>
#     <button onclick="animb8f0ea935fd54542981f4bf2aaf225fc.last_frame()"><i class="fa fa-fast-forward">
#         </i></button>
#     <button onclick="animb8f0ea935fd54542981f4bf2aaf225fc.faster()"><i class="fa fa-plus"></i></button>
#   <form action="#n" name="_anim_loop_selectb8f0ea935fd54542981f4bf2aaf225fc" class="anim_control">
#     <input type="radio" name="state"
#            value="once" > Once </input>
#     <input type="radio" name="state"
#            value="loop" checked> Loop </input>
#     <input type="radio" name="state"
#            value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgb8f0ea935fd54542981f4bf2aaf225fc";
#     var slider_id = "_anim_sliderb8f0ea935fd54542981f4bf2aaf225fc";
#     var loop_select_id = "_anim_loop_selectb8f0ea935fd54542981f4bf2aaf225fc";
#     var frames = new Array(0);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADl0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uIDIuMi4yLCBo\
# dHRwOi8vbWF0cGxvdGxpYi5vcmcvhp/UCwAAIABJREFUeJzsfWeQZGd57tN5OsxO3pmdoN3JYfPu\
# zAZJBdglwMi3UIEw4EIWQbahLIINosCBMpjww7aMEDayMHZxjS3Awthy2SVhq7jU5VoSWm2QdqWd\
# 1D2xpyf1zHROJ9wf6+/s6Z4OJ3ynT4fzVE1pNeGc06f7fM/3vu/zPq+J53keBgwYMGDAQJXBrPcF\
# GDBgwIABA0pgEJgBAwYMGKhKGARmwIABAwaqEgaBGTBgwICBqoRBYAYMGDBgoCphEJgBAwYMGKhK\
# GARmwIABAwaqEgaBGTBgwICBqoRBYAYMGDBgoCphEJgBAwYMGKhKGARmwIABAwaqEgaBGTBgwICB\
# qoRBYAYMGDBgoCphEJgBAwYMGKhKGARmwIABAwaqEgaBGTBgwICBqoRBYAYMGDBgoCph1fsCDBhQ\
# C57nkclkwLIsLBYLzGYzLBYLTCaT3pdmwIABDWEQmIGqBc/zYBhG+MpkMjCbzcLPCJFZrVaB2Mxm\
# s0FsBgzUCEw8z/N6X4QBA3IgJi4AMJlMYFkWDMNkERj5L/kixGUymWCxWLK+DGIzYKD6YERgBqoG\
# HMcJRAXcIiIxKYlR6PuE2FiWxbVr1zA4OAin0wkAQsQmJjWD2AwYqFwYBGag4sFxHCKRCGKxGFpa\
# WrKISy7ExCYmLEJsJBUphkFsBgxUJgwCM1Cx4DgODMOAZVlEo1FsbW2hra2N2vFNJpNAXKUiNoPY\
# DBioPBgEZqDiwHEcMpkMOI4DcLtmpUW5ttQxDWIzYKByYRCYgYoAEVrkEpeYQGgTmBpCUUps5Mtm\
# sxnEZsCAShgEZkBXlCIuAq0ITCtSLERsmUwGV69exZkzZ4SfGRGbAQPKYBCYAV3A87xQ4+I4TiCt\
# Qou22WwWCI72dZQD5HURYrJYLML5CYGn0+ms128QmwEDxWFYSRkoK3ieB8uySKfTSKfTQn9WKWUh\
# 7WiJ53l8+ctfxsTEBN7ylrfghRdeyIqKygWxGpI0XBOyIsSWSCQQi8UQiUQQCoUQDocRj8eRTCYF\
# BxKjndNAPcKIwAyUBYS4GIaRTFpilCIwuVHJiy++iEuXLuHSpUvo6uoCAFy5ckXWMbREoXtDIrZ0\
# Oo2lpSWcOnUKW1tbWeQnttN6/fXX8cgjj+Dy5csIBoMG0RmoKRgRmAFNQVwzUqmUIGogaTA5pCMn\
# AiONzsWwvLyMQ4cOCU3M1YLc/jUAAmFxHId0Oo14PI5YLIZwOIxkMol3vvOd+Na3vgUAQsrWIDID\
# tQCDwAxoAkJcu7u7mJubAwBV9ZtSNbCxsTE89thjuHjxIrq6usAwDAKBAB544AH09/fj+PHjeOKJ\
# JwAAf//3f49PfOITuH79OkZHR/HVr34VP//5zzE2NiYc79ixY3j88cdx8eJF9Pb24kMf+hCSyaTw\
# 82effRZ33XUX+vr6cM899+DGjRtZf/uNb3xDuJaHH34Ym5ubePe7343e3l488sgj2N3dFX7/5Zdf\
# xj333IO+vj7ceeed+PnPfy787N5778WXv/xlvPWtb0V3dzfuu+8+BINBAMA73vEOAEBfXx+6u7tx\
# 6dKlfanI0dFRPPDAAxgaGgIARKNRhMNhhEIhRCIRxONxpFIpg9gMVCUMAjNAFbkRF3HRUCs8kBKB\
# /ehHP8LTTz+NlZUVmM1mvO9978OxY8cwMzODf/u3f8MTTzyB559/Hg8++CAee+wxHD9+HNPT0/jD\
# P/zDvMf78Y9/jB//+Md47bXXcOPGDfzjP/4jAODVV1/Fww8/jMceewyLi4v48Ic/jPe///1IpVLC\
# 3z7zzDN45plncOXKFTz77LO4//778cd//MeYn58Hx3H467/+awDA2toafu3Xfg2f/

# %%
plt.close()

# %%
def draw_3d_graph(valnew_dict, num_points=100, n_agents=2):
    fig = plt.figure()
    ax = Axes3D(fig)
    np.random.seed(0)
    
    unif=np.random.rand(num_points, n_agents)
    k_sample=k_bar+(unif)*(k_up-k_bar)
    
    print('fig size: {0} DPI, size in inches {1}'.format(
        fig.get_dpi(), fig.get_size_inches()))

    ax.scatter([],[],[])

    def update(i):
        label = 'refinement {0}'.format(i+1)
        ax.scatter(k_sample[:,0], k_sample[:,1],valnew_dict[i].evaluateBatch(k_sample),color='blue')
        ax.set_title(label)

    anim = FuncAnimation(fig, update, frames=np.arange(0, 16), interval=1000)
    return anim

anim = draw_3d_graph(valnew_dict)
HTML(anim.to_jshtml())
# Out:
# fig size: 72.0 DPI, size in inches [6. 4.]
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_imgf5dc3cdd4f3b4f66b1df6278ed1f482b">
#     <br>
#     <input id="_anim_sliderf5dc3cdd4f3b4f66b1df6278ed1f482b" type="range" style="width:350px"
#            name="points" min="0" max="1" step="1" value="0"
#            onchange="animf5dc3cdd4f3b4f66b1df6278ed1f482b.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="animf5dc3cdd4f3b4f66b1df6278ed1f482b.slower()"><i class="fa fa-minus"></i></button>
#     <button onclick="animf5dc3cdd4f3b4f66b1df6278ed1f482b.first_frame()"><i class="fa fa-fast-backward">
#         </i></button>
#     <button onclick="animf5dc3cdd4f3b4f66b1df6278ed1f482b.previous_frame()">
#         <i class="fa fa-step-backward"></i></button>
#     <button onclick="animf5dc3cdd4f3b4f66b1df6278ed1f482b.reverse_animation()">
#         <i class="fa fa-play fa-flip-horizontal"></i></button>
#     <button onclick="animf5dc3cdd4f3b4f66b1df6278ed1f482b.pause_animation()"><i class="fa fa-pause">
#         </i></button>
#     <button onclick="animf5dc3cdd4f3b4f66b1df6278ed1f482b.play_animation()"><i class="fa fa-play"></i>
#         </button>
#     <button onclick="animf5dc3cdd4f3b4f66b1df6278ed1f482b.next_frame()"><i class="fa fa-step-forward">
#         </i></button>
#     <button onclick="animf5dc3cdd4f3b4f66b1df6278ed1f482b.last_frame()"><i class="fa fa-fast-forward">
#         </i></button>
#     <button onclick="animf5dc3cdd4f3b4f66b1df6278ed1f482b.faster()"><i class="fa fa-plus"></i></button>
#   <form action="#n" name="_anim_loop_selectf5dc3cdd4f3b4f66b1df6278ed1f482b" class="anim_control">
#     <input type="radio" name="state"
#            value="once" > Once </input>
#     <input type="radio" name="state"
#            value="loop" checked> Loop </input>
#     <input type="radio" name="state"
#            value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgf5dc3cdd4f3b4f66b1df6278ed1f482b";
#     var slider_id = "_anim_sliderf5dc3cdd4f3b4f66b1df6278ed1f482b";
#     var loop_select_id = "_anim_loop_selectf5dc3cdd4f3b4f66b1df6278ed1f482b";
#     var frames = new Array(0);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADl0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uIDIuMi4yLCBo\
# dHRwOi8vbWF0cGxvdGxpYi5vcmcvhp/UCwAAIABJREFUeJzsfXl8XGW9/nPOmX0me5MmTdrsTdc0\
# dKGL7BdBENACAioIlNUL/FAE7E/UC8LVq9cr2IsooKhXgSrKhR9gK5so0GLSJd1pM5PJvm+zb2f5\
# /XF4T85MZp+TTJKe5/PJB5rMvOc92/u83+35UoIgCFChQoUKFSrmGOhsT0CFChUqVKhIByqBqVCh\
# QoWKOQmVwFSoUKFCxZyESmAqVKhQoWJOQiUwFSpUqFAxJ6ESmAoVKlSomJNQCUyFChUqVMxJqASm\
# QoUKFSrmJFQCU6FChQoVcxIqgalQoUKFijkJlcBUqFChQsWchEpgKlSoUKFiTkIlMBUqVKhQMSeh\
# EpgKFSpUqJiTUAlMhQoVKlTMSagEpkKFChUq5iRUAlOhQoUKFXMSmmxPQIWKTCEIAkKhEDiOA8Mw\
# oGkaDMOAoqhsT02FChXTCJXAVMxZCIIAlmWln1AoBJqmpb8RItNoNBKx0TStEpsKFfMElCAIQrYn\
# oUJFKpATFwBQFAWO48CybBiBkf+SH0JcFEWBYZiwH5XYVKiYe1AtMBVzBjzPS0QFiEQkJyU5Yv2e\
# EBvHcWhtbUVtbS2MRiMASBabnNRUYlOhYvZCJTAVsx48z8Pr9WJkZAQLFy4MI65UISc2OWERYiOu\
# SDlUYlOhYnZCJTAVsxY8z4NlWXAch0AggIGBAZSVlSk2PkVREnElsthUYlOhYvZBJTAVsw48zyMU\
# CoHneQCTMavpCNcmGlMlNhUqZi9UAlMxK0ASLSKJS04gShNYJoSiEpsKFdmHSmAqsopExEUwXQQ2\
# XaQYj9haW1tRV1cHvV4PQCU2FSrShUpgKrICQRCkGBfP8xJpxVq0aZqWCE7pecwEIolNnjxCCDwY\
# DIadv0psKlTEhyolpWJGIQgCOI5DMBhEMBiU6rMSZRYqbS0JgoBHH30UK1aswHnnnYc9e/Zg7dq1\
# io2fLOTZkKTgmpAVITafzwePxwOXywWHwwGn0wmv1wu/3y8pkKjlnCpOR6gWmIoZASEulmWTJi05\
# 4hHYxMQErFYr/H4/jEYjLBYLzGYzzGYzjEajVNwsx969e9HS0oKWlhaUlpYCAA4cOJD+CSqMWNeG\
# WGzBYBCdnZ1oamrC8PBwGPnJ5bSOHTuG+++/H/v378fo6KhKdCrmFVQCUzGtiEZc0QglEaK5EMfH\
# x2Gz2cAwDOrq6qDT6RAMBjExMQGPx4OhoSH4fD4AgMlkkkjNYrGgq6sLZWVlUhHzXIGc2BiGkf5L\
# rg+xxshn/H4/rrjiCtxyyy249tprJbWSTGrpVKiYLVBdiCqmBUTuye124+jRowCgWPxmbGwMLS0t\
# 6OzsRENDA8444wyceeaZ2LFjB/7lX/4FjY2NWLx4MYqKivDTn/4U11xzDa655hr88Y9/hMvlwuOP\
# P4677roLR44cwdKlS/Hggw/ijTfeQENDg2ShrFq1Cjt27MDmzZtRUVGBm266CX6/X5rDrl278KlP\
# fQqLFy/GhRdeKJ0j+e5Pf/pTbN68GaWlpbjrrrswNDSEK6+8EosWLcK9996LiYkJ6fPNzc248MIL\
# sXjxYmzZsgXvv/++9LdLL70Ujz76KD796U9j0aJF+NznPofR0VEAwCWXXAIAWLx4MRYtWoSWlpYp\
# rsiGhgZcf/31qKurAwCcPHkSTqcTDocDLpcLXq8XgUBAikWqFpqKuQSVwFQoCkJcgUBASiN3uVyK\
# EBfLsmhubkZ3dzeWLVuGpqYm5OTkSH//05/+hJdeegnd3d2gaRrXXnstVq1ahZMnT+L111/H73//\
# e7S3t+Nb3/oWduzYgdWrV+PgwYP4+te/DpfLBZZl0dLSgv379yMUCmHnzp147rnns

# %%
plt.close()
