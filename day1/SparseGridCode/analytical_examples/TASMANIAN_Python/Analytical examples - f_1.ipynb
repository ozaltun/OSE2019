# %%
from helper import *

# %%
function = f_1
function_string = 'f_1'

# %%
data2d = main(function, 2, function_name=function_string, refinement_level = 10)
# Out:
#  ----------------
# TasmanianSG version: 4.0
# TasmanianSG license: BSD 3-Clause
# Using fixed sparse grid with depth 5
# Classic refinement
#
#  ----------------

# %%
fig, ax = plt.subplots(1, 2, sharey=True, figsize=(10, 5))
fig.tight_layout()

ax[0].axis([-1,1,-1,1])
ax[1].axis([-1,1,-1,1])

print('fig size: {0} DPI, size in inches {1}'.format(
    fig.get_dpi(), fig.get_size_inches()))

x = data2d[0]['aPoints'][:,0]
y = data2d[0]['aPoints'][:,1]

ax[0].scatter(x, y)
ax[1].scatter([],[])

def update(i):
    label = 'refinement {0}'.format(i+1)
    ax[1].scatter(data2d[1][i+1]['aPoints'][:,0], data2d[1][i+1]['aPoints'][:,1],color='blue')
    ax[1].set_title(label)

anim = FuncAnimation(fig, update, frames=np.arange(0, 10), interval=1000)
HTML(anim.to_jshtml())
# Out:
# fig size: 72.0 DPI, size in inches [10.  5.]
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_img3888eb75ca6a4d8ebd56a13a9fa148e6">
#     <br>
#     <input id="_anim_slider3888eb75ca6a4d8ebd56a13a9fa148e6" type="range" style="width:350px"
#            name="points" min="0" max="1" step="1" value="0"
#            onchange="anim3888eb75ca6a4d8ebd56a13a9fa148e6.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="anim3888eb75ca6a4d8ebd56a13a9fa148e6.slower()"><i class="fa fa-minus"></i></button>
#     <button onclick="anim3888eb75ca6a4d8ebd56a13a9fa148e6.first_frame()"><i class="fa fa-fast-backward">
#         </i></button>
#     <button onclick="anim3888eb75ca6a4d8ebd56a13a9fa148e6.previous_frame()">
#         <i class="fa fa-step-backward"></i></button>
#     <button onclick="anim3888eb75ca6a4d8ebd56a13a9fa148e6.reverse_animation()">
#         <i class="fa fa-play fa-flip-horizontal"></i></button>
#     <button onclick="anim3888eb75ca6a4d8ebd56a13a9fa148e6.pause_animation()"><i class="fa fa-pause">
#         </i></button>
#     <button onclick="anim3888eb75ca6a4d8ebd56a13a9fa148e6.play_animation()"><i class="fa fa-play"></i>
#         </button>
#     <button onclick="anim3888eb75ca6a4d8ebd56a13a9fa148e6.next_frame()"><i class="fa fa-step-forward">
#         </i></button>
#     <button onclick="anim3888eb75ca6a4d8ebd56a13a9fa148e6.last_frame()"><i class="fa fa-fast-forward">
#         </i></button>
#     <button onclick="anim3888eb75ca6a4d8ebd56a13a9fa148e6.faster()"><i class="fa fa-plus"></i></button>
#   <form action="#n" name="_anim_loop_select3888eb75ca6a4d8ebd56a13a9fa148e6" class="anim_control">
#     <input type="radio" name="state"
#            value="once" > Once </input>
#     <input type="radio" name="state"
#            value="loop" checked> Loop </input>
#     <input type="radio" name="state"
#            value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img3888eb75ca6a4d8ebd56a13a9fa148e6";
#     var slider_id = "_anim_slider3888eb75ca6a4d8ebd56a13a9fa148e6";
#     var loop_select_id = "_anim_loop_select3888eb75ca6a4d8ebd56a13a9fa148e6";
#     var frames = new Array(0);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADl0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uIDIuMi4yLCBo\
# dHRwOi8vbWF0cGxvdGxpYi5vcmcvhp/UCwAAIABJREFUeJzt3X90lOWd//9XSASD9ZMAG344YTUh\
# IQohhu1EsDlVCEYWPQZdUfH4I/7A0MLWlt1Fs0ulek5ZwrEf+zn+wk1lJV23RqVuYsUFcaPuHo4K\
# o8nXYNWmElkYUhqSkNoKCYTr+wedMTETnHvuZO57uJ+PczxL7rnve95cXHvx7nDd80oyxhgBAADP\
# +p//+R/dfPPN+uSTT3TOOec4XU5MPvvsM2VlZen48eNKSUmJeM6ePXv093//93rvvffU0dEhWiDE\
# apTTBQAAgJFz4sSJrz1n3759uuCCCxK2eY7WWWedpRtvvFGbNm1yuhQkOBpoAADOMBdccIE2bNig\
# goICnXPOOTpx4oQOHjyo66+/XhkZGcrKytKjjz4qSdq0aZOWLVumt99+W9/4xjf0ox/9SG+++aYy\
# MzMH3O8nP/mJCgoKlJaWpptuuknHjh0Lv/7KK6+osLBQ6enp+ta3vqUPPvhgwLUPP/xwuJa7775b\
# hw4d0qJFi3TuuefqiiuuUFdXV/j8d955R9/61reUnp6uiy++WG+++Wb4tXnz5umBBx5QcXGxzj33\
# XF155ZU6fPiwJOmyyy6TJKWnp+sb3/iG3n777UHjkpeXp7vvvlszZ84cnoGGdxkAAHBGOf/8883F\
# F19s/vd//9d88cUXpq+vz/zVX/2Veeihh0xPT4/59NNPTVZWltm2bZsxxphnnnnGFBcXh69/4403\
# jM/nG3C/oqIiEwwGTUdHh7nwwgvNxo0bjTHGvP/++yYjI8O888475sSJE2bz5s3m/PPPN8eOHQtf\
# O2fOHPO73/3OHDhwwGRkZJjZs2eb999/3xw9etTMnz/fPPjgg8YYYw4cOGDGjx9vtm7davr6+sxr\
# r71mxo8fb37/+98bY4y5/PLLTXZ2tvnkk0/MF198YS6//HJz//33G2OMaW1tNZLM8ePHv3Z8Wlpa\
# DC0Q7OATaAAAzkD33nuvpk6dqtTUVO3evVvt7e1au3atRo8erezsbN1zzz2qra21dL/zzjtP48eP\
# 1zXXXKOmpiZJUnV1tZYvX645c+YoOTlZ5eXlGjNmjN55553wtd/73vc0adIk+Xw+ffvb39acOXM0\
# e/ZsnX322bruuuvU2NgoSXr22Wd11VVX6aqrrtKoUaNUWloqv9+vV199NXyvO++8U9OnT1dqaqpu\
# vPHGcB1APEXeZQ8AABLa1KlTw7/et2+fDh48qPT09PCxvr4+ffvb3476fpMnTw7/euzYsTp48GD4\
# 3jU1NXrsscfCr/f29oZfl6RJkyaFf52amjro5z/+8Y/he7344ov61a9+FX79+PHjmj9//pB1hK4F\
# 4okGGgCAM1BSUlL411OnTlVWVpZaWlqG/X2mTp2qNWvWaM2aNcNyr9tuu00/+9nPLF/b//cLjDS2\
# cAAAcIa75JJLdO6552rDhg06evSo+vr6tGfPHu3evdv2ve+55x499dRTevfdd2WM0Z/+9Cdt3bpV\
# n3/+ueV73XrrrfrVr36l7du3q6+vT8eOHdObb76pAwcOfO21GRkZGjVqlPbu3TvkOcYYHTt2TL29\
# vZKkY8eOqaenx3KdAA00AABnuOTkZL3yyitqampSVlaW/uIv/kLLli1Td3e37Xv7/X797Gc/09/+\
# 7d9q3LhxysnJ0ebNm2O619SpU1VfX69//ud/VkZGhqZOnaqHH35YJ0+e/Nprx44dqzVr1qi4uFjp\
# 6ekD9mCH7Nu3T6mpqeFv4UhNTVVeXl5MtcLbkozhW8QBAACAaPEJNAAAAGDBkA30XXfdpYkTJyo/\
# Pz/i68YY3XvvvcrJyVFBQYHef//98Gs1NTXKzc1Vbm6uampqhr9qAAAAwCFDNtB33

# %%
plt.close()

# %%
HTML(draw_3d(data2d).to_jshtml())
# Out:
# fig size: 72.0 DPI, size in inches [6. 4.]
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_img13b91b0e923a4d258ec6adcd714629e1">
#     <br>
#     <input id="_anim_slider13b91b0e923a4d258ec6adcd714629e1" type="range" style="width:350px"
#            name="points" min="0" max="1" step="1" value="0"
#            onchange="anim13b91b0e923a4d258ec6adcd714629e1.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="anim13b91b0e923a4d258ec6adcd714629e1.slower()"><i class="fa fa-minus"></i></button>
#     <button onclick="anim13b91b0e923a4d258ec6adcd714629e1.first_frame()"><i class="fa fa-fast-backward">
#         </i></button>
#     <button onclick="anim13b91b0e923a4d258ec6adcd714629e1.previous_frame()">
#         <i class="fa fa-step-backward"></i></button>
#     <button onclick="anim13b91b0e923a4d258ec6adcd714629e1.reverse_animation()">
#         <i class="fa fa-play fa-flip-horizontal"></i></button>
#     <button onclick="anim13b91b0e923a4d258ec6adcd714629e1.pause_animation()"><i class="fa fa-pause">
#         </i></button>
#     <button onclick="anim13b91b0e923a4d258ec6adcd714629e1.play_animation()"><i class="fa fa-play"></i>
#         </button>
#     <button onclick="anim13b91b0e923a4d258ec6adcd714629e1.next_frame()"><i class="fa fa-step-forward">
#         </i></button>
#     <button onclick="anim13b91b0e923a4d258ec6adcd714629e1.last_frame()"><i class="fa fa-fast-forward">
#         </i></button>
#     <button onclick="anim13b91b0e923a4d258ec6adcd714629e1.faster()"><i class="fa fa-plus"></i></button>
#   <form action="#n" name="_anim_loop_select13b91b0e923a4d258ec6adcd714629e1" class="anim_control">
#     <input type="radio" name="state"
#            value="once" > Once </input>
#     <input type="radio" name="state"
#            value="loop" checked> Loop </input>
#     <input type="radio" name="state"
#            value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img13b91b0e923a4d258ec6adcd714629e1";
#     var slider_id = "_anim_slider13b91b0e923a4d258ec6adcd714629e1";
#     var loop_select_id = "_anim_loop_select13b91b0e923a4d258ec6adcd714629e1";
#     var frames = new Array(0);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADl0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uIDIuMi4yLCBo\
# dHRwOi8vbWF0cGxvdGxpYi5vcmcvhp/UCwAAIABJREFUeJzsfXmQG2eZ/tM6R9Lcl+eyZzyH77HH\
# 9zgcFUJCirCYYyEHCTEb2A0p2GKXCmAIBJIf+SXUbhHCsRxFdpNdWJIABc5uhQSy2XDGHtvxFdsZ\
# j47RXJpDGo1uqXX07w//vs4nTbfU3TpGUvqpciWWp/tradTf0+/7Pu/zMhzHcVChQoUKFSoqDJq1\
# vgAVKlSoUKFCCVQCU6FChQoVFQmVwFSoUKFCRUVCJTAVKlSoUFGRUAlMhQoVKlRUJFQCU6FChQoV\
# FQmVwFSoUKFCRUVCJTAVKlSoUFGRUAlMhQoVKlRUJFQCU6FChQoVFQmVwFSoUKFCRUVCJTAVKlSo\
# UFGRUAlMhQoVKlRUJFQCU6FChQoVFQmVwFSoUKFCRUVCJTAVKlSoUFGRUAlMhQoVKlRUJHRrfQEq\
# VOQLjuMQj8eRTCah1Wqh0Wig1WrBMMxaX5oKFSqKCJXAVFQsaOJKJBKIx+PQaK4mFZaXl2EymVBX\
# VwedTscTm0ajUYlNhYoqgUpgKioOHMchkUggkUjglVdewTXXXMNHXYTAAoEAAMBsNiORSIDjOJ64\
# GIaBVqtViU2FigqHSmAqKgapVIqPtoCrRET/oUH+TgiNgOM4AODPQxMbIUHyRyU2FSrKGyqBqSh7\
# pFIpJBIJJJNJABAkrEwwDMOTVebr9H8JyM+SVCQNldhUqChPqASmomyhhLgIxAgs28/T/yUQI7Z4\
# PI5QKIS2tjaV2FSoWCOoBKai7JBKpRCPx5FKpQDIIy4CuQSW7Tz0fwkikQjm5+fR1NSkRmwqVKwR\
# VAJTURbgOI5XFeZDXASFIrBs5wfEa2xqKlKFiuJDJTAVa4pCExdBKQhMaY2NZdm0f1eJTYUKZVAJ\
# TMWagOM4vsZ1+fJl9PT0oLa2VtGmnUqlMDs7i1AohNraWlgsFn6NcgFNbHTURhN4JrFFo1HU1NSg\
# pqZGJTYVKgSgWkmpKCk4jkMymQTLsmBZlv97KpWSvTGnUimwLItXXnkF0WgUdXV1iEQicDqdcDqd\
# mJycxGuvvQaHw4HFxUWEw2Ge1DiOwz333IMNGzbg2muvxV/+8hfs2bOnGG85Kwih0X1phKxmZ2ex\
# srKCSCSCUCiEQCAAn88Hv9+PcDiMaDTKN3KXE1mrUFEqqBGYipKAEBXde0X+aDQaPn0oBclkEjMz\
# M5iZmQHHcThw4AC0Wi1YluWjm7m5OSSTSTQ3NyMUCiEUCmFhYQGRSAQMw+DKlSv43e9+hz/96U9o\
# a2tDTU0NXn31VcnXUIoUJflsdLo3blMSsbEsC6fTiZGRESwtLaWRH22ndfHiRdx77704ffo0PB6P\
# SnQqqgoqgakoKoSIK1P4IJUMkskkpqenMTs7i87OThw8eBBjY2PQ6XRpxycSCT6as1gsfEqRIJVK\
# 4dKlS+jp6UE8HsfExASi0Sg0Gg3/8+SP0Wgsq5QdXR/UarX8f8lDAInGyM9Eo1EcPnwYH//4x3HL\
# LbcgkUjwachyel8qVCiBmkJUURQQu6dYLMar8cTqN7kisEQiAbvdjuPHj4PjOBw8eBD9/f3Q6XQ8\
# +W3ZsgXf+ta3cOjQIXR0dCCZTGJhYQF33HEHNm7ciOHhYXz/+98HAPzkJz/Bvffei7Nnz+Ktb30r\
# /uu//guxWAx33HEHenp6oNfrcc011+BrX/saRkZG0NnZiQ9+8IOwWq1YXl4Gy7J44YUXcOTIEaxf\
# vx7XX389XnvtNf56d+zYgccee4y/lk996lNYXFzEBz/4QXR1deHw4cPwer38z4+NjeH666/H+vXr\
# cc011+CPf/wj/xnecsst+D//5//ghhtuQFdXF973vvfB4/EAAN797ncDANavX4+ur

# %%
plt.close()

# %%
fig, ax = draw_plots(data2d)
plt.show()

# %%
data5d = main(function, 5, function_name=function_string, refinement_level = 7)
# Out:
#  ----------------
# TasmanianSG version: 4.0
# TasmanianSG license: BSD 3-Clause
# Using fixed sparse grid with depth 5
# Classic refinement
#
#  ----------------

# %%
fig, ax = draw_plots(data5d)
plt.show()
