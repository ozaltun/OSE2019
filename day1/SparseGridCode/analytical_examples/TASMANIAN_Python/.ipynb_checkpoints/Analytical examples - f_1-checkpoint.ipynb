# %%
from helper import *

# %%
function = f_1
function_string = 'f_1'

# %%
data2d = main(function, 2, function_name=function_string, refinement_level = 10)
# Out:
#  ----------------
# TasmanianSG version: 4.0
# TasmanianSG license: BSD 3-Clause
# Using fixed sparse grid with depth 5
# Classic refinement
#
#  ----------------

# %%
fig, ax = plt.subplots(1, 2, sharey=True, figsize=(10, 5))
fig.tight_layout()

ax[0].axis([-1,1,-1,1])
ax[1].axis([-1,1,-1,1])

print('fig size: {0} DPI, size in inches {1}'.format(
    fig.get_dpi(), fig.get_size_inches()))

x = data2d[0]['aPoints'][:,0]
y = data2d[0]['aPoints'][:,1]

ax[0].scatter(x, y)
ax[1].scatter([],[])

def update(i):
    label = 'refinement {0}'.format(i+1)
    ax[1].scatter(data2d[1][i+1]['aPoints'][:,0], data2d[1][i+1]['aPoints'][:,1],color='blue')
    ax[1].set_title(label)

anim = FuncAnimation(fig, update, frames=np.arange(0, 10), interval=1000)
HTML(anim.to_jshtml())
# Out:
# fig size: 72.0 DPI, size in inches [10.  5.]
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_img76c87d900de94ca5b642d1b7197e1f9c">
#     <br>
#     <input id="_anim_slider76c87d900de94ca5b642d1b7197e1f9c" type="range" style="width:350px"
#            name="points" min="0" max="1" step="1" value="0"
#            onchange="anim76c87d900de94ca5b642d1b7197e1f9c.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="anim76c87d900de94ca5b642d1b7197e1f9c.slower()"><i class="fa fa-minus"></i></button>
#     <button onclick="anim76c87d900de94ca5b642d1b7197e1f9c.first_frame()"><i class="fa fa-fast-backward">
#         </i></button>
#     <button onclick="anim76c87d900de94ca5b642d1b7197e1f9c.previous_frame()">
#         <i class="fa fa-step-backward"></i></button>
#     <button onclick="anim76c87d900de94ca5b642d1b7197e1f9c.reverse_animation()">
#         <i class="fa fa-play fa-flip-horizontal"></i></button>
#     <button onclick="anim76c87d900de94ca5b642d1b7197e1f9c.pause_animation()"><i class="fa fa-pause">
#         </i></button>
#     <button onclick="anim76c87d900de94ca5b642d1b7197e1f9c.play_animation()"><i class="fa fa-play"></i>
#         </button>
#     <button onclick="anim76c87d900de94ca5b642d1b7197e1f9c.next_frame()"><i class="fa fa-step-forward">
#         </i></button>
#     <button onclick="anim76c87d900de94ca5b642d1b7197e1f9c.last_frame()"><i class="fa fa-fast-forward">
#         </i></button>
#     <button onclick="anim76c87d900de94ca5b642d1b7197e1f9c.faster()"><i class="fa fa-plus"></i></button>
#   <form action="#n" name="_anim_loop_select76c87d900de94ca5b642d1b7197e1f9c" class="anim_control">
#     <input type="radio" name="state"
#            value="once" > Once </input>
#     <input type="radio" name="state"
#            value="loop" checked> Loop </input>
#     <input type="radio" name="state"
#            value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img76c87d900de94ca5b642d1b7197e1f9c";
#     var slider_id = "_anim_slider76c87d900de94ca5b642d1b7197e1f9c";
#     var loop_select_id = "_anim_loop_select76c87d900de94ca5b642d1b7197e1f9c";
#     var frames = new Array(0);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADl0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uIDIuMi4yLCBo\
# dHRwOi8vbWF0cGxvdGxpYi5vcmcvhp/UCwAAIABJREFUeJzt3X90lOWd//9XSASD9ZMAG344YTUh\
# IQohhu1EsDlVCEYWPQZdUfH4I/7A0MLWlt1Fs0ulek5ZwrEf+zn+wk1lJV23RqVuYsUFcaPuHo4K\
# o8nXYNWmElkYUhqSkNoKCYTr+wedMTETnHvuZO57uJ+PczxL7rnve95cXHvx7nDd80oyxhgBAADP\
# +p//+R/dfPPN+uSTT3TOOec4XU5MPvvsM2VlZen48eNKSUmJeM6ePXv093//93rvvffU0dEhWiDE\
# apTTBQAAgJFz4sSJrz1n3759uuCCCxK2eY7WWWedpRtvvFGbNm1yuhQkOBpoAADOMBdccIE2bNig\
# goICnXPOOTpx4oQOHjyo66+/XhkZGcrKytKjjz4qSdq0aZOWLVumt99+W9/4xjf0ox/9SG+++aYy\
# MzMH3O8nP/mJCgoKlJaWpptuuknHjh0Lv/7KK6+osLBQ6enp+ta3vqUPPvhgwLUPP/xwuJa7775b\
# hw4d0qJFi3TuuefqiiuuUFdXV/j8d955R9/61reUnp6uiy++WG+++Wb4tXnz5umBBx5QcXGxzj33\
# XF155ZU6fPiwJOmyyy6TJKWnp+sb3/iG3n777UHjkpeXp7vvvlszZ84cnoGGdxkAAHBGOf/8883F\
# F19s/vd//9d88cUXpq+vz/zVX/2Veeihh0xPT4/59NNPTVZWltm2bZsxxphnnnnGFBcXh69/4403\
# jM/nG3C/oqIiEwwGTUdHh7nwwgvNxo0bjTHGvP/++yYjI8O888475sSJE2bz5s3m/PPPN8eOHQtf\
# RUVFpS5RBUxFRUVFpS5RBUxFRUVFpS5RBUxFRUVFpS5RBUxFRUVFpS5RBUxFRUVFpS5RBUxFRUVF\
# pS5RBUxFRUVFpS5RBUxFRUVFpS5RBUxFRUVFpS5RBUxFRUVFpS7RVfsEVFTEwrIs0uk0aJqGVquF\
# RqOBVqsFRVHVPjUVFRUZUQVMpW7hC1cmk0E6nYZGczWp4PP5YDKZ0NLSAp1OxwmbRqNRhU1FpUFQ\
# BUyl7mBZFplMBplMBmfPnsV73vMeLuoiAhYOhwEAZrMZmUwGLMtywkVRFLRarSpsKip1jipgKnUD\
# wzBctAVcFSKKohCPx7G4uIhUKgWLxYLm5mZOtIigEViWBQBuP3xhIyJIvlRhU1GpbSiWXNEqKjUK\
# wzDIZDKgaRrANeGKRqN45ZVXYLFYMDQ0BL1ej3g8jkgkgq2tLdA0Db1eD7PZjObmZk7cjEZjniiR\
# y4BlWeReEqqwqajUJqqAqdQsxYQrHA5jcXERyWQSiUQC73vf+8AwTNYamNPphNFoRHd3N2KxGKLR\
# KPcVj8eh0Wg4YSNflQhbOp1GNBpFd3e3KmwqKlVCTSGq1BxEjBiGAXBNuEKhEOx2OzKZDEZHR9HZ\
# 2Ynf/OY3BQWDoiguhWixWGCxWLJ+TtM0J2zBYBCrq6tIJBLQaDRZotbc3Iympqa8VGQ8Hsf6+jo6\
# OjqQTqezfqZGbCoqyqAKmEpNQCKcQsIVCARgt9sBAKOjo2hvb992f0TAiqHVatHS0oKWlpas79M0\
# zUVqfr8fKysrSCaT0Gq1WaLGF8jc1wGAq4rkowqbioq0qAKmUlVKCZff74fdbodWq8XY2Bja2trK\
# 3u92AlYMrVaL1tZWtLa2Zn0/k8kgFoshEonA6/UiFAohGo3iwoUL3Noa+TIYDEVTkZlMBqlUKuvn\
# qrCpqAhDFTCVqsCyLLfG9fbbb2NgYIBL8/l8PiwuLkKv12NycjIvSioHoQJWDJ1OlyVssVgMi4uL\
# mJqa4iI2j8eDpaUlpNNp6HS6LFGzWCzQ6/WgKCorauMLeK6wJRIJGI1GGI1GVdhUVAqgCpiKovCF\
# i2EYUBQFmqZB0zQ8Hg8WFxdhMpmwd+/evHUrIccq9bNPf/rT+I//+A+MjIzgK1/5Cj7zmc/gtdde\
# q+gYOp0ObW1tedEhKfKIRqPY2trihE2v1+etsen1+oLn53a70dXVhba2tryITafTZfW+qcKm8m5E\
# FTAVRWBZNq/3itxwE4kELl26hPb2dhw4cABms7ni/efevLeLwM6ePYv//u//xttvv43m5mYAqEi8\
# ttu/Xq9He3t73npdKpXihG1jYwPRaBSZTAYGgyFP2Ei0ptNdu0xJxJZKpeB0OjEzM4OtrS2uKZuf\
# htRqtbh8+TIeeOABXLhwAV6vV9KoVEWl2qgCpiIrhYRLo9GAZVlsbGzA4XCApmmMjo5i165dgo/B\
# J5PJbCswy8vL2L17NydeSmEwGGAwGNDR0cF9j6QQI5EIotEo1tbWEI1GEYvFEAwG0d7eniVsWq0W\
# ALL+q9FouEZvfnN2IpHA6dOn8YlPfAK33norMpkMF62pEZtKvaO60avIArF7SiaTX

# %%
plt.close()

# %%
fig, ax = draw_plots(data2d)
plt.show()

# %%
data5d = main(function, 5, function_name=function_string, refinement_level = 7)
# Out:
#  ----------------
# TasmanianSG version: 4.0
# TasmanianSG license: BSD 3-Clause
# Using fixed sparse grid with depth 5
# Classic refinement
#
#  ----------------

# %%
fig, ax = draw_plots(data5d)
plt.show()
