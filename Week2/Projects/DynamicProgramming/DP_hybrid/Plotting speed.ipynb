# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
from mpl_toolkits.mplot3d import Axes3D
from IPython.display import HTML
# %matplotlib notebook

# %%
def plot_data(root):
    data = np.loadtxt(root) 
    # Column 1 is points, column 2 is number of processes, column 3 is number of threads, column 4 is error
    fig = plt.figure()
    fig.tight_layout()
    ax = fig.add_subplot(111, projection='3d')
    dem3d=ax.plot_surface(data[:,1].reshape(4, 4), data[:,2].reshape(4, 4), data[:,3].reshape(4,4))
    ax.set_xlabel('Number of units')
    ax.set_ylabel('Number of threads')
    ax.set_zlabel('Time (s)')
    ax.set_title('Number of grid points:{}'.format(root.split('_')[0]))

# %%
plot_data('1000_test.txt')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plot_data('5000_test.txt')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plot_data('10000_test.txt')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig = plt.figure()
fig.tight_layout()
ax = fig.add_subplot(111, projection='3d')


for i in ['1000_test.txt','5000_test.txt','10000_test.txt']:
    data = np.loadtxt(i) 
    # Column 1 is points, column 2 is number of processes, column 3 is number of threads, column 4 is error

    ax.scatter(data[:,1].reshape(4, 4), data[:,2].reshape(4, 4), data[:,3].reshape(4,4), label='grid points:{}'.format(i.split('_')[0]))
    ax.set_xlabel('Number of units')
    ax.set_ylabel('Number of threads')
    ax.set_zlabel('Time (s)')
ax.legend()
    
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
data = np.loadtxt('100000_test.txt')

# %%
data
# Out:
# array([[1.00000000e+05, 8.00000000e+00, 4.00000000e+00, 2.04514164e+02,
#         2.32353500e+00],
#        [1.00000000e+05, 8.00000000e+00, 8.00000000e+00, 1.08889653e+02,
#         2.32683900e+00],
#        [1.00000000e+05, 8.00000000e+00, 1.20000000e+01, 8.18173470e+01,
#         2.42295200e+00],
#        [1.00000000e+05, 1.00000000e+01, 4.00000000e+00, 1.64133283e+02,
#         2.52543900e+00],
#        [1.00000000e+05, 1.00000000e+01, 8.00000000e+00, 8.74076140e+01,
#         2.45413400e+00],
#        [1.00000000e+05, 1.00000000e+01, 1.20000000e+01, 6.69892960e+01,
#         2.45321500e+00]])

# %%
# Column 1 is points, column 2 is number of processes, column 3 is number of threads, column 4 is error
fig = plt.figure()
fig.tight_layout()
ax = fig.add_subplot(111, projection='3d')
dem3d=ax.plot_surface(data[:,1].reshape(2, 3), data[:,2].reshape(2, 3), data[:,3].reshape(2,3))
ax.set_xlabel('Number of units')
ax.set_ylabel('Number of threads')
ax.set_zlabel('Time (s)')
ax.set_title('Number of grid points: 100,000')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5,0.92,'Number of grid points: 100,000')
