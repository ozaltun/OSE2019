# %%
import os
os.environ["Method"] = "stochastic"
import nonlinear_solver_initial as solver     #solves opt. problems for terminal VF
import nonlinear_solver_iterate as solviter   #solves opt. problems during VFI
import interpolation as interpol              #interface to sparse grid library/terminal VF
import interpolation_iter as interpol_iter    #interface to sparse grid library/iteration
import postprocessing as post                 #computes the L2 and Linfinity error of the model
from parameters import *
import TasmanianSG                            #sparse grid library
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
from mpl_toolkits.mplot3d import Axes3D
from IPython.display import HTML

# %%
def main():
    valnew_dict = dict()
    # terminal value function
    valnew=TasmanianSG.TasmanianSparseGrid()
    if (numstart==0):
        valnew=interpol.sparse_grid(n_agents, iDepth)
        valnew_dict[numstart] = valnew
        valnew.write("valnew_1." + str(numstart) + ".txt") #write file to disk for restart

    # value function during iteration
    else:
        valnew_dict[numstart] = valnew
        valnew.read("valnew_1." + str(numstart) + ".txt")  #write file to disk for restart

    valold=TasmanianSG.TasmanianSparseGrid()
    valold=valnew

    for i in range(numstart, numits):
        valnew=TasmanianSG.TasmanianSparseGrid()
        valnew=interpol_iter.sparse_grid_iter(n_agents, iDepth, valold)
        valold=TasmanianSG.TasmanianSparseGrid()
        valold=valnew
        valnew_dict[i+1] = valnew
        valnew.write("valnew_1." + str(i+1) + ".txt")

    #======================================================================
    print( "===============================================================")
    print( " " )
    print( " Computation of a growth model of dimension ", n_agents ," finished after ", numits, " steps")
    print( " " )
    print( "===============================================================")
    #======================================================================

    # compute errors   
    avg_err=post.ls_error(n_agents, numstart, numits, No_samples)
    
    #======================================================================
    print( "===============================================================")
    print( " ")
    print( " Errors are computed -- see errors.txt")
    print( " ")
    print( "===============================================================")
    #======================================================================
    return valnew_dict

# %%
valnew_dict = main()
errors = np.loadtxt('errors.txt')
# Out:
# ===============================================================
#
# (' Computation of a growth model of dimension ', 2, ' finished after ', 15, ' steps')
#
# ===============================================================
# ===============================================================
#
#  Errors are computed -- see errors.txt
#
# ===============================================================

# %%
valnew_dict[10].plotResponse2D()
# Out:
# <module 'matplotlib.pyplot' from '/software/python-2.7.12-el7-x86_64/lib/python2.7/site-packages/matplotlib/pyplot.pyc'>

# %%
def draw_plots(errors):
    refinement = errors[:,0]
    error_max = errors[:,1]
    error_mean = errors[:,2]
    
    fig, ax = plt.subplots(1, 2, figsize=(10,5))
    ax[0].scatter(refinement, error_max)
    ax[0].set_xlabel('Refinement')
    ax[0].set_ylabel('Max Error')
    
    ax[1].scatter(refinement, error_mean)
    ax[1].set_xlabel('Refinement')
    ax[1].set_ylabel('Mean Error')
    
    return fig, ax

fig, ax = draw_plots(errors)
plt.show()

# %%
def draw_3d_grid(valnew_dict):
    fig = plt.figure()
    ax = Axes3D(fig)
    
    print('fig size: {0} DPI, size in inches {1}'.format(
        fig.get_dpi(), fig.get_size_inches()))

    ax.scatter([],[],[])

    def update(i):
        label = 'refinement {0}'.format(i+1)
        ax.scatter(valnew_dict[i].getPoints()[:,0], valnew_dict[i].getPoints()[:,1],valnew_dict[i].evaluateBatch(valnew_dict[i].getPoints()),color='blue')
        ax.set_title(label)

    anim = FuncAnimation(fig, update, frames=np.arange(0, 16), interval=1000)
    return anim

anim = draw_3d_grid(valnew_dict)
HTML(anim.to_jshtml())
# Out:
# fig size: 72.0 DPI, size in inches [6. 4.]
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_img0e03a2e9c84f47fda687ccc00a46b43e">
#     <br>
#     <input id="_anim_slider0e03a2e9c84f47fda687ccc00a46b43e" type="range" style="width:350px"
#            name="points" min="0" max="1" step="1" value="0"
#            onchange="anim0e03a2e9c84f47fda687ccc00a46b43e.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="anim0e03a2e9c84f47fda687ccc00a46b43e.slower()"><i class="fa fa-minus"></i></button>
#     <button onclick="anim0e03a2e9c84f47fda687ccc00a46b43e.first_frame()"><i class="fa fa-fast-backward">
#         </i></button>
#     <button onclick="anim0e03a2e9c84f47fda687ccc00a46b43e.previous_frame()">
#         <i class="fa fa-step-backward"></i></button>
#     <button onclick="anim0e03a2e9c84f47fda687ccc00a46b43e.reverse_animation()">
#         <i class="fa fa-play fa-flip-horizontal"></i></button>
#     <button onclick="anim0e03a2e9c84f47fda687ccc00a46b43e.pause_animation()"><i class="fa fa-pause">
#         </i></button>
#     <button onclick="anim0e03a2e9c84f47fda687ccc00a46b43e.play_animation()"><i class="fa fa-play"></i>
#         </button>
#     <button onclick="anim0e03a2e9c84f47fda687ccc00a46b43e.next_frame()"><i class="fa fa-step-forward">
#         </i></button>
#     <button onclick="anim0e03a2e9c84f47fda687ccc00a46b43e.last_frame()"><i class="fa fa-fast-forward">
#         </i></button>
#     <button onclick="anim0e03a2e9c84f47fda687ccc00a46b43e.faster()"><i class="fa fa-plus"></i></button>
#   <form action="#n" name="_anim_loop_select0e03a2e9c84f47fda687ccc00a46b43e" class="anim_control">
#     <input type="radio" name="state"
#            value="once" > Once </input>
#     <input type="radio" name="state"
#            value="loop" checked> Loop </input>
#     <input type="radio" name="state"
#            value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img0e03a2e9c84f47fda687ccc00a46b43e";
#     var slider_id = "_anim_slider0e03a2e9c84f47fda687ccc00a46b43e";
#     var loop_select_id = "_anim_loop_select0e03a2e9c84f47fda687ccc00a46b43e";
#     var frames = new Array(0);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADl0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uIDIuMi4yLCBo\
# dHRwOi8vbWF0cGxvdGxpYi5vcmcvhp/UCwAAIABJREFUeJzsvXl0JGd5Lv70qtbSWkbLaLRLo200\
# iz2LZzGOj8nBZklOuMZgG/ANEHLgnkAuHDAJWQgHCEtyIBhDgOTmAieQy56ELSYBwpLg8Yw8i8fj\
# sSX1ppbUai3dUu9bVdfvj/l95a9LVd219Tr1nKMD1khfV7eqvud73/d5n9fEcRwHAwYMGDBgoM5g\
# rvYFGDBgwIABA2pgEJgBAwYMGKhLGARmwIABAwbqEgaBGTBgwICBuoRBYAYMGDBgoC5hEJgBAwYM\
# GKhLGARmwIABAwbqEgaBGTBgwICBuoRBYAYMGDBgoC5hEJgBAwYMGKhLGARmwIABAwbqEgaBGTBg\
# wICBuoRBYAYMGDBgoC5hEJgBAwYMGKhLGARmwIABAwbqEgaBGTBgwICBuoRBYAYMGDBgoC5hrfYF\
# GDCgFRzHIZfLgWVZWCwWmM1mWCwWmEymal+aAQMGygiDwAzULTiOA8Mw/Fcul4PZbOb/jRCZ1Wrl\
# ic1sNhvEZsBAg8DEcRxX7YswYEAJaOICAJPJBJZlwTBMAYGR/yVfhLhMJhMsFkvBl0FsBgzUH4wI\
# zEDdIJ/P80QF3CQimpRoSH2fEBvLsrh69SoOHjyI5uZmAOAjNprUDGIzYKB2YRCYgZpHPp9HLBZD\
# IpFAV1dXAXEpBU1sNGERYiOpSBoGsRkwUJswCMxAzSKfz4NhGLAsi3g8jq2tLXR3d+u2vslk4omr\
# VMRmEJsBA7UHg8AM1Bzy+TxyuRzy+TyAF2tW5SjXllrTIDYDBmoXBoEZqAkQoYWQuGgC0ZvAtBCK\
# WmIjXzabzSA2AwY0wiAwA1VFKeIiKBeBlYsUpYgtl8vhypUrOHHiBP9vRsRmwIA6GARmoCrgOI6v\
# ceXzeZ60pDZts9nME5ze11EJkPdFiMlisfCvTwg8m80WvH+D2AwYKA7DSspARcFxHFiWRTabRTab\
# 5fuzSikLi0VLHMdhc3MTq6urCIfDyGQyJYmJ4zh85CMfwdzcHO655x48+eSTBVFRpUCrIUnDNSEr\
# QmypVAqJRAKxWAyRSATRaBTJZBLpdJp3IDHaOQ3cijAiMAMVASEuhmFkkxYNMQLjOA4bGxvwer1w\
# Op1obW1FKBSC3+9HNpuF1WpFa2sr/9XW1gabzQYAOH/+PObn5zE/P4/+/n4AwOXLl/V90xog9dmQ\
# iC2bzWJ5eRm33347tra2CsiPttN67rnn8Oijj+LSpUsIhUIG0RloKBgEZqCsECMu4pahBDSBcRyH\
# YDAIr9eLzs5OHD9+HHa7HdlsFmazGQzDwGq1IpfLIZFIIJFIYGtrC16vFwzDwGaz4eLFi+jr6+Ov\
# zWqtj0eBJjaShiSERRq9adeRdDqN3/md38Fb3/pWPPTQQ7xbiZZeOgMGagVGCtFAWUDsnnZ2drC0\
# tAQAmuo3ZrMZLMsiEAjg/Pnz2N3dxYkTJzA3NweHw4HZ2Vk89thjOHfuHPr7+8EwDLa3t/HOd74T\
# d911Fx544AFcuHABp0+fxpUrV/DRj34UN27cwIkTJ/Dud78bf//3f4+DBw/C5XJhfX0dc3Nz/HpD\
# Q0N485vfjHQ6zV/PE088gZe85CUYHh7Gy172Mly/fp3/tyNHjuAzn/kMfy3veMc7sLm5ide85jUY\
# GhrCo48+ip2dHf7nL168iJe97GUYHh7GnXfeif/6r//i/+1Vr3oVPvKRj+Dee+/FwMAAXv3qVyMU\
# CgEAXvnKVwIAhoeHMTAwgPn5+T2pyJmZGTzyyCOYnJwEAMTjcUSjUUQiEcRiMSSTSWQyGb4WaURo\
# BuoJBoEZ0BWEuDKZDK8sjMVimk77+XwewWAQOzs7iMViOHnyJA4dOgSHw1Hwc9/5z

# %%
plt.close()

# %%
def draw_3d_graph(valnew_dict, num_points=100, n_agents=2):
    fig = plt.figure()
    ax = Axes3D(fig)
    np.random.seed(0)
    
    unif=np.random.rand(num_points, n_agents)
    k_sample=k_bar+(unif)*(k_up-k_bar)
    
    print('fig size: {0} DPI, size in inches {1}'.format(
        fig.get_dpi(), fig.get_size_inches()))

    ax.scatter([],[],[])

    def update(i):
        label = 'refinement {0}'.format(i+1)
        ax.scatter(k_sample[:,0], k_sample[:,1],valnew_dict[i].evaluateBatch(k_sample),color='blue')
        ax.set_title(label)

    anim = FuncAnimation(fig, update, frames=np.arange(0, 16), interval=1000)
    return anim

anim = draw_3d_graph(valnew_dict)
HTML(anim.to_jshtml())
# Out:
# fig size: 72.0 DPI, size in inches [6. 4.]
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_imged6ca42188a34518adc1a5e006fe2db7">
#     <br>
#     <input id="_anim_slidered6ca42188a34518adc1a5e006fe2db7" type="range" style="width:350px"
#            name="points" min="0" max="1" step="1" value="0"
#            onchange="animed6ca42188a34518adc1a5e006fe2db7.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="animed6ca42188a34518adc1a5e006fe2db7.slower()"><i class="fa fa-minus"></i></button>
#     <button onclick="animed6ca42188a34518adc1a5e006fe2db7.first_frame()"><i class="fa fa-fast-backward">
#         </i></button>
#     <button onclick="animed6ca42188a34518adc1a5e006fe2db7.previous_frame()">
#         <i class="fa fa-step-backward"></i></button>
#     <button onclick="animed6ca42188a34518adc1a5e006fe2db7.reverse_animation()">
#         <i class="fa fa-play fa-flip-horizontal"></i></button>
#     <button onclick="animed6ca42188a34518adc1a5e006fe2db7.pause_animation()"><i class="fa fa-pause">
#         </i></button>
#     <button onclick="animed6ca42188a34518adc1a5e006fe2db7.play_animation()"><i class="fa fa-play"></i>
#         </button>
#     <button onclick="animed6ca42188a34518adc1a5e006fe2db7.next_frame()"><i class="fa fa-step-forward">
#         </i></button>
#     <button onclick="animed6ca42188a34518adc1a5e006fe2db7.last_frame()"><i class="fa fa-fast-forward">
#         </i></button>
#     <button onclick="animed6ca42188a34518adc1a5e006fe2db7.faster()"><i class="fa fa-plus"></i></button>
#   <form action="#n" name="_anim_loop_selected6ca42188a34518adc1a5e006fe2db7" class="anim_control">
#     <input type="radio" name="state"
#            value="once" > Once </input>
#     <input type="radio" name="state"
#            value="loop" checked> Loop </input>
#     <input type="radio" name="state"
#            value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imged6ca42188a34518adc1a5e006fe2db7";
#     var slider_id = "_anim_slidered6ca42188a34518adc1a5e006fe2db7";
#     var loop_select_id = "_anim_loop_selected6ca42188a34518adc1a5e006fe2db7";
#     var frames = new Array(0);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADl0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uIDIuMi4yLCBo\
# dHRwOi8vbWF0cGxvdGxpYi5vcmcvhp/UCwAAIABJREFUeJzsnXmYHGW5t++q3mdJZksm22SbGSYb\
# 2TEJqEc5HJRV2VEWARVB0OBnEBQ9CIKAHEQWiRvCOUc2EQ+IoiJ7JAIhgYQQIJmefc2s3dN7d1V9\
# fxRV6enpnunuqZ6eCXVfVy5lpuet6u6q91fP8z7v7xEURVEwMTExMTGZYoj5PgETExMTE5NsMAXM\
# xMTExGRKYgqYiYmJicmUxBQwExMTE5MpiSlgJiYmJiZTElPATExMTEymJKaAmZiYmJhMSUwBMzEx\
# MTGZkpgCZmJiYmIyJTEFzMTExMRkSmIKmImJiYnJlMQUMBMTExOTKYkpYCYmJiYmUxJTwExMTExM\
# piSmgJmYmJiYTElMATMxMTExmZKYAmZiYmJiMiWx5vsETEzGi6IoRKNRJEnCYrEgiiIWiwVBEPJ9\
# aiYmJjnEFDCTKYuiKMRiMf1fNBpFFEX9d5qQWa1WXdhEUTSFzcTkMEFQFEXJ90mYmGRCvHABCIKA\
# JEnEYrFhAqb9r/ZPEy5BELBYLMP+mcJmYjL1MCMwkymDLMu6UIEqRPGiFE+qn2vCJkkSb7/9NtXV\
# 1bhcLgA9YosXNVPYTEwmL6aAmUx6ZFkmEAjQ29tLZWXlMOHKlHhhixcsTdi0VGQ8prCZmExOTAEz\
# mbTIskwsFkOSJMLhMF1dXcyePduw8QVB0IVrrIjNFDYTk8mHKWAmkw5ZlolGo8iyDBxas8rFcu1Y\
# Y5rCZmIyeTEFzGRSoBVaJApXvIAYLWDjERRT2ExM8o8pYCZ5ZSzh0siVgOVKFEcTtrfffpuamhoc\
# DgdgCpuJSbaYAmaSFxRF0de4ZFnWRSvVpC2Koi5wRp/HRJAobPHFI5qARyKRYe/fFDYTk9ExraRM\
# JhRFUZAkiUgkQiQS0fdnjVVZaHS0pCgKP/rRj1i2bBmf+tSn2L59O2vXrjVs/HSJr4bUNlxrYqUJ\
# WzAYxO/3MzQ0hMfjwev1EggECIVCugOJuZ3T5KOIGYGZTAiacMVisbRFK56xBCzTqORf//oXO3bs\
# YMeOHcyaNQuAXbt2ZTRGLkn12WgRWyQSobm5mdWrV9PT0zNM/OLttN599122bNnCzp076evrM4XO\
# 5LDCjMBMcormmhEOh/WiBi0NlonojJVCHBoaoqenB7/fTyQSGXO8lpYWZs+erW9iniok7l8DdMGS\
# ZZlIJEIgEMDv9+P1egmFQpx66qncd999AHrK1hQyk8MBU8BMcoImXD6fj7179wLkZP3G4/Gwa9cu\
# Vq1axb333svHP/5xZs+ezWuvvcZLL73EaaedxsKFC1m+fDlbt24F4H/+53/4xje+wTvvvENdXR03\
# 33wz27ZtY8mSJfq4K1as4O6772bTpk3MmzePiy66iFAopP/+r3/9K8cccwxVVVUcd9xx+nvU/vau\
# u+5i06ZNzJo1iyuuuIKDBw9y+umnM2fOHDZv3szg4KD++jfeeIPjjjuOqqoqjj76aLZt26b/7sQT\
# T+RHP/oR//Ef/8GcOXP43Oc+R19fHwAnnHACAFVVVcyZM4cdO3aMSEXW1dVx/vnnU1NTA8AHH3yA\
# 1+vF4/EwNDREIBAgHA6bwmYyJTEFzMRQkkVcQ0ND4xauxL/3eDzs3LmT+vp6Fi9ejN1u5/nnn+fp\
# p5+mra2N9evXc91117F8+XL+/ve/81//9V/ceeedbN26laOOOoof/OAHLF++nD179vC9730v6TH/\
# +Mc/8sc//pE9e/awd+9eHnroIQB2797NFVdcwc9+9jOampq4+OKLOffccwmHw/rfPvXUUzz11FPs\
# 2rWLv/71r5xxxhlcf/31NDQ0oCgKv/71rwHo6OjgrLPO4uqrr6a5uZmbbrqJ888/n

# %%
plt.close()
