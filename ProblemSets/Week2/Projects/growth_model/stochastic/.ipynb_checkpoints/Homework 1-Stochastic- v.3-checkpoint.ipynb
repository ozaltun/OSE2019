# %%
import os
os.environ["Method"] = "stochastic"
import nonlinear_solver_initial as solver     #solves opt. problems for terminal VF
import nonlinear_solver_iterate as solviter   #solves opt. problems during VFI
import interpolation as interpol              #interface to sparse grid library/terminal VF
import interpolation_iter as interpol_iter    #interface to sparse grid library/iteration
import postprocessing as post
import TasmanianSG                            #sparse grid library
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
from mpl_toolkits.mplot3d import Axes3D
from IPython.display import HTML

# %%
paramL = dict()
# Depth of "Classical" Sparse grid
paramL['iDepth']=1
paramL['iOut']=1         # how many outputs
paramL['which_basis'] = 1 #linear basis function (2: quadratic local basis)

# control of iterations
paramL['numstart'] = 0   # which is iteration to start (numstart = 0: start from scratch, number=/0: restart)
paramL['numits'] = 5    # which is the iteration to end

# How many random points for computing the errors
paramL['No_samples'] = 200

### Model Paramters
paramL['n_agents']=2  # number of continuous dimensions of the model

paramL['beta']=0.5
paramL['rho']=0.95
paramL['zeta']=0.5
paramL['psi']=0.36
paramL['gamma']=2.0
paramL['delta']=0.025
paramL['eta']=1
paramL['big_A']=(1.0-paramL['beta'])/(paramL['psi']*paramL['beta'])

# Ranges For States
paramL['range_cube']=5 # range of [0..1]^d in 1D
paramL['k_bar']=0.2
paramL['k_up']=3.0

# Ranges for Controls
paramL['c_bar']=1e-2
paramL['c_up']=10000.0

paramL['l_bar']=1e-2
paramL['l_up']=1.0

paramL['inv_bar']=1e-2
paramL['inv_up']=10000.0

# Stochastic
paramL['theta_list'] = [0.9, 0.95, 1.00, 1.05, 1.10]
paramL['curr_theta'] = 1.00

# %%
#valList = []
output = dict()
if (paramL['numstart']==0):
    output[paramL['numstart']] = dict()
    for state in range(5):
        paramL['curr_theta'] = paramL['theta_list'][state]
        valnew=TasmanianSG.TasmanianSparseGrid()
        valnew=interpol.sparse_grid(paramL)
        #valList.append(valnew)
        valnew.write("valnew_1." + str(paramL['numstart']) +".s{}".format(state)+ ".txt") #write file to disk for restart
        output[paramL['numstart']][state] = valnew
# value function during iteration
else:
    for state in range(5):
        valnew.read("valnew_1." + str(paramL['numstart']) +".s{}".format(state)+ ".txt") #write file to disk for restart
        valList.append(valnew)


valListold = []
for state in range(5):
    valold=TasmanianSG.TasmanianSparseGrid()
    valold.read("valnew_1." + str(paramL['numstart']) +".s{}".format(state)+ ".txt")
    valListold.append(valold)

# %%
def draw_3d_graph(tSGrid, num_points=300, n_agents=2):
    fig = plt.figure()
    ax = Axes3D(fig)
    np.random.seed(0)
    
    unif=np.random.rand(num_points, n_agents)
    k_sample=paramL['k_bar']+(unif)*(paramL['k_up']-paramL['k_bar'])


    z=tSGrid.evaluateBatch(k_sample) 
    ax.scatter(k_sample[:,0], k_sample[:,1],z)
    
    return fig, ax

# %%
print(valListold)
# Out:
# [<TasmanianSG.TasmanianSparseGrid instance at 0x7fe1a0602830>, <TasmanianSG.TasmanianSparseGrid instance at 0x7fe1a0659098>, <TasmanianSG.TasmanianSparseGrid instance at 0x7fe145962fc8>, <TasmanianSG.TasmanianSparseGrid instance at 0x7fe1457df638>, <TasmanianSG.TasmanianSparseGrid instance at 0x7fe1457d5908>]

# %%
for state in range(5):
    paramL['curr_theta'] = paramL['theta_list'][state]
    valnew=TasmanianSG.TasmanianSparseGrid()
    valnew=interpol_iter.sparse_grid_iter(paramL, valListold)
    valnew.write("valnew_1."+str(1)+".s{}".format(state)+".txt")
    print(valnew.evaluateBatch(valnew.getPoints()))
# Out:
# [[ 0.14405718]
#  [-0.52609244]
#  [ 0.37306572]
#  [-0.52609244]
#  [ 0.37306572]]
# [[ 0.24348159]
#  [-0.38988321]
#  [ 0.46306986]
#  [-0.38988321]
#  [ 0.46306986]]
# [[ 0.3341679 ]
#  [-0.26652366]
#  [ 0.54518558]
#  [-0.26652366]
#  [ 0.54518558]]
# [[ 0.41726447]
#  [-0.15425414]
#  [ 0.62044686]
#  [-0.15425414]
#  [ 0.62044686]]
# [[ 0.49372301]
#  [-0.05162449]
#  [ 0.68971129]
#  [-0.05162449]
#  [ 0.68971129]]

# %%
valListold = []
for state in range(5):
    valold=TasmanianSG.TasmanianSparseGrid()
    valold.read("valnew_1." + str(paramL['numstart']) +".s{}".format(state)+ ".txt")
    valListold.append(valold)

# %%
for state in range(5):
    paramL['curr_theta'] = paramL['theta_list'][state]
    valnew=TasmanianSG.TasmanianSparseGrid()
    valnew=interpol_iter.sparse_grid_iter(paramL, valListold)
    valnew.write("valnew_1."+str(1)+".s{}".format(state)+".txt")
    print(valnew.evaluateBatch(valnew.getPoints()))
# Out:
# [[ 0.14405718]
#  [-0.52609244]
#  [ 0.37306572]
#  [-0.52609244]
#  [ 0.37306572]]
# [[ 0.24348159]
#  [-0.38988321]
#  [ 0.46306986]
#  [-0.38988321]
#  [ 0.46306986]]
# [[ 0.3341679 ]
#  [-0.26652366]
#  [ 0.54518558]
#  [-0.26652366]
#  [ 0.54518558]]
# [[ 0.41726447]
#  [-0.15425414]
#  [ 0.62044686]
#  [-0.15425414]
#  [ 0.62044686]]
# [[ 0.49372301]
#  [-0.05162449]
#  [ 0.68971129]
#  [-0.05162449]
#  [ 0.68971129]]

# %%
for i in range(paramL['numstart'], paramL['numits']):
    for state in range(5):
        paramL['curr_theta'] = paramL['theta_list'][state]
        valnew=TasmanianSG.TasmanianSparseGrid()
        valnew=interpol_iter.sparse_grid_iter(paramL, valListold)
        valnew.write("valnew_1."+str(i+1)+".s{}".format(state)+".txt")
        if state ==0:
            print(valnew.evaluateBatch(valnew.getPoints()))
    valListold = []
    for state in range(5):
        valold=TasmanianSG.TasmanianSparseGrid()
        valold.read("valnew_1." + str(i+1) +".s{}".format(state)+ ".txt")
        valListold.append(valold)

# compute errors   
avg_err=post.ls_error(paramL)
# Out:
# [[ 0.14405718]
#  [-0.52609244]
#  [ 0.37306572]
#  [-0.52609244]
#  [ 0.37306572]]
# [[ 0.14405718]
#  [-0.52609244]
#  [ 0.37306572]
#  [-0.52609244]
#  [ 0.37306572]]
# [[ 0.14405718]
#  [-0.52609244]
#  [ 0.37306572]
#  [-0.52609244]
#  [ 0.37306572]]
# [[ 0.14405718]
#  [-0.52609244]
#  [ 0.37306572]
#  [-0.52609244]
#  [ 0.37306572]]
# [[ 0.14405718]
#  [-0.52609244]
#  [ 0.37306572]
#  [-0.52609244]
#  [ 0.37306572]]

# %%
plt.close()
def draw_plots():
    
    fig, ax = plt.subplots(1, 2, figsize=(10,5))
    for i in range(5):
        errors = np.loadtxt('errors.s{}.txt'.format(i))
        refinement = errors[:,0]
        error_max = errors[:,1]
        error_mean = errors[:,2]
        ax[0].scatter(refinement, error_max, label='state={}'.format(i))
        ax[0].set_xlabel('Refinement')
        ax[0].set_ylabel('Max Error')

        ax[1].scatter(refinement, error_mean, label='state={}'.format(i))
        ax[1].set_xlabel('Refinement')
        ax[1].set_ylabel('Mean Error')
    
    ax[0].legend()
    ax[1].legend()
    
    return fig, ax

fig, ax = draw_plots()
plt.show()

# %%
def draw_3d_graph(refinement, num_points=300, n_agents=2):
    fig = plt.figure()
    ax = Axes3D(fig)
    np.random.seed(0)
    
    unif=np.random.rand(num_points, n_agents)
    k_sample=paramL['k_bar']+(unif)*(paramL['k_up']-paramL['k_bar'])
    

    label = 'refinement {0}'.format(refinement+1)
    for j in range(5):
        v=TasmanianSG.TasmanianSparseGrid()
        v.read("valnew_1." + str(refinement) +'.s{}'.format(j)+ ".txt")
        z=v.evaluateBatch(k_sample) 


        ax.scatter(k_sample[:,0], k_sample[:,1],z, label=j)

    ax.set_title(label)
    
    return fig, ax

fig, ax = draw_3d_graph(5)

plt.show()

# %%
def draw_3d_graph(num_points=500, n_agents=2):
    fig = plt.figure()
    ax = Axes3D(fig)
    np.random.seed(0)
    
    unif=np.random.rand(num_points, n_agents)
    k_sample=paramL['k_bar']+(unif)*(paramL['k_up']-paramL['k_bar'])
    

    def update(i):
        label = 'refinement {0}'.format(i+1)
        ax = Axes3D(fig)
        for j in range(5):
            v=TasmanianSG.TasmanianSparseGrid()
            v.read("valnew_1." + str(i) +'.s{}'.format(j)+ ".txt")
            z=v.evaluateBatch(k_sample) 
            ax.scatter(k_sample[:,0], k_sample[:,1],z, label=j, s = 1)
    
        ax.set_title(label)
        ax.legend()
        
    anim = FuncAnimation(fig, update, frames=np.arange(0, 5), interval=1000)
    return anim

anim = draw_3d_graph()
HTML(anim.to_jshtml())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_img9b9849ea06eb4bfeb8b4fe759235b840">
#     <br>
#     <input id="_anim_slider9b9849ea06eb4bfeb8b4fe759235b840" type="range" style="width:350px"
#            name="points" min="0" max="1" step="1" value="0"
#            onchange="anim9b9849ea06eb4bfeb8b4fe759235b840.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="anim9b9849ea06eb4bfeb8b4fe759235b840.slower()"><i class="fa fa-minus"></i></button>
#     <button onclick="anim9b9849ea06eb4bfeb8b4fe759235b840.first_frame()"><i class="fa fa-fast-backward">
#         </i></button>
#     <button onclick="anim9b9849ea06eb4bfeb8b4fe759235b840.previous_frame()">
#         <i class="fa fa-step-backward"></i></button>
#     <button onclick="anim9b9849ea06eb4bfeb8b4fe759235b840.reverse_animation()">
#         <i class="fa fa-play fa-flip-horizontal"></i></button>
#     <button onclick="anim9b9849ea06eb4bfeb8b4fe759235b840.pause_animation()"><i class="fa fa-pause">
#         </i></button>
#     <button onclick="anim9b9849ea06eb4bfeb8b4fe759235b840.play_animation()"><i class="fa fa-play"></i>
#         </button>
#     <button onclick="anim9b9849ea06eb4bfeb8b4fe759235b840.next_frame()"><i class="fa fa-step-forward">
#         </i></button>
#     <button onclick="anim9b9849ea06eb4bfeb8b4fe759235b840.last_frame()"><i class="fa fa-fast-forward">
#         </i></button>
#     <button onclick="anim9b9849ea06eb4bfeb8b4fe759235b840.faster()"><i class="fa fa-plus"></i></button>
#   <form action="#n" name="_anim_loop_select9b9849ea06eb4bfeb8b4fe759235b840" class="anim_control">
#     <input type="radio" name="state"
#            value="once" > Once </input>
#     <input type="radio" name="state"
#            value="loop" checked> Loop </input>
#     <input type="radio" name="state"
#            value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img9b9849ea06eb4bfeb8b4fe759235b840";
#     var slider_id = "_anim_slider9b9849ea06eb4bfeb8b4fe759235b840";
#     var loop_select_id = "_anim_loop_select9b9849ea06eb4bfeb8b4fe759235b840";
#     var frames = new Array(0);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADl0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uIDIuMi4yLCBo\
# dHRwOi8vbWF0cGxvdGxpYi5vcmcvhp/UCwAAIABJREFUeJzsvXeYHGeZr31Xdc7dM9PTk7OkmVHO\
# siTLlnFYZ4yxDceAjQ14WVjM+ny7wHph8cces8bAArtnYQlLMmE/Fi/giG1s4ShLVrAtK03OeXo6\
# x6r6/mh1q3uCZkbTkkZy3dc1lzTdVW+/U11Vv3rC+zyCoigKKioqKioq5xniuZ6AioqKiorK6aAK\
# mIqKiorKeYkqYCoqKioq5yWqgKmoqKionJdoz/UEVFRUVFTOHYlEgt7eXqLR6LmeyowYjUYqKirQ\
# 6XQ5rwtqFqKKiorKu5eOjg5sNhuFhYUIgnCupzMFRVEYGxsjEAhQW1ub857qQlR5V6IoCh/96Edx\
# uVxs2rSJl156iWXLlp3raamonHWi0eiiFS8AQRAoLCyc1kJUBUzlXcnLL7/Ms88+S29vL3v27OHi\
# iy/m2LFj53pa86KzsxNBEEgmkzNuc+jQIa666iqKiooW7Q1K5dyz2M+NmeanCpjKBcepbuhpurq6\
# qKmpwWKxnIUZnTt0Oh233norP/rRj871VFRUZuTpp59m2bJlNDQ08M///M9z3k8VMJULgpqaGh56\
# 6CFWrVqFxWIhmUzS39/PzTffjNvtpra2lu985zsA/OhHP+JjH/sYr732GlarlX/8x39k165dVFRU\
# 5Iz39a9/nVWrVuFwOLjttttyXBiPP/44a9aswel0snXrVt56662cfR9++OHMXO6++26Ghoa4+uqr\
# sdlsXH755Xi93sz2u3fvZuvWrTidTlavXs2uXbsy71166aV88YtfZNu2bdhsNq688kpGR0cB2LFj\
# BwBOpxOr1cprr7025bgsW7aMu+++m+XLl+fnQKuo5BlJkvjUpz7FU089xeHDh/nVr37F4cOH57az\
# oqJyAVBdXa2sXr1a6e7uVsLhsCJJkrJu3TrlgQceUGKxmNLW1qbU1tYqTz/9tKIoivLjH/9Y2bZt\
# W2b/F154QSkvL88Zb+PGjUpfX58yNjamNDY2Kt/97ncVRVGU/fv3K263W9m9e7eSTCaVn/zkJ0p1\
# dbUSjUYz+27evFkZHBxUent7Fbfbraxdu1bZv3+/EolElJ07dypf/vKXFUVRlN7eXqWgoEB54okn\
# FEmSlGeeeUYpKChQhoeHFUVRlEsuuUSpq6tTjh07poTDYeWSSy5RPve5zymKoigdHR0KoCQSiVmP\
# T0tLi6Je7irTcfjw4XP6+a+++qpy5ZVXZn5/8MEHlQcffHDKdtPNU7XAVC4YPvOZz1BZWYnJZGLv\
# 3r2MjIzwpS99Cb1eT11dHR//+Mf59a9/Pa/xysrKKCgo4Prrr+fgwYMAfP/73+eee+5h8+bNaDQa\
# 7rjjDgwGA7t3787s+9d//dd4PB7Ky8u5+OKL2bx5M2vXrsVoNHLTTTdx4MABAB555BGuueYarrnm\
# GkRR5IorrmDDhg08+eSTmbE++tGPsnTpUkwmE7feemtmHioqFwJ9fX1UVlZmfq+oqKCvr29O+6rr\
# wFQuGLIvgq6uLvr7+3E6nZnXJEni4osvnvN4JSUlmf+bzWb6+/szY//0pz/lX//1XzPvx+PxzPsA\
# Ho8n83+TyTTl92AwmBnrN7/5DY899ljm/UQiwc6dO2ecR3pfFZVzxXgozm/e6OGWDZUUWPTnbB6q\
# gKlcMGRnKlVWVlJbW0tLS0veP6eyspL777+f+++/Py9jffjDH+YHP/jBvPdd7JljKhcuv3mjh68+\
# dRSAey6pX9BY5eXl9PT0ZH7v7e2lvLx8TvuqLkSVC5JNmzZhs9l46KGHiEQiSJLEoUOH2Lt374LH\
# /vjHP873vvc9Xn/9dRRFIRQK8cQTTxAIBOY91oc+9CEee+wx/vjHPyJJEtFolF27d
