# %%
from helper import *

# %%
function = f_5
function_string = 'f_5'

# %%
data2d = main(function, 2, function_name=function_string, refinement_level = 10)
# Out:
#  ----------------
# TasmanianSG version: 4.0
# TasmanianSG license: BSD 3-Clause
# Using fixed sparse grid with depth 5
# Classic refinement
#
#  ----------------

# %%
fig, ax = plt.subplots(1, 2, sharey=True, figsize=(10, 5))
fig.tight_layout()

ax[0].axis([-1,1,-1,1])
ax[1].axis([-1,1,-1,1])

print('fig size: {0} DPI, size in inches {1}'.format(
    fig.get_dpi(), fig.get_size_inches()))

x = data2d[0]['aPoints'][:,0]
y = data2d[0]['aPoints'][:,1]

ax[0].scatter(x, y)
ax[1].scatter([],[])

def update(i):
    label = 'refinement {0}'.format(i+1)
    ax[1].scatter(data2d[1][i+1]['aPoints'][:,0], data2d[1][i+1]['aPoints'][:,1],color='blue')
    ax[1].set_title(label)

anim = FuncAnimation(fig, update, frames=np.arange(0, 10), interval=1000)
HTML(anim.to_jshtml())
# Out:
# fig size: 72.0 DPI, size in inches [10.  5.]
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_imgb36a6234b0584cd2b2c927da0598da3e">
#     <br>
#     <input id="_anim_sliderb36a6234b0584cd2b2c927da0598da3e" type="range" style="width:350px"
#            name="points" min="0" max="1" step="1" value="0"
#            onchange="animb36a6234b0584cd2b2c927da0598da3e.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="animb36a6234b0584cd2b2c927da0598da3e.slower()"><i class="fa fa-minus"></i></button>
#     <button onclick="animb36a6234b0584cd2b2c927da0598da3e.first_frame()"><i class="fa fa-fast-backward">
#         </i></button>
#     <button onclick="animb36a6234b0584cd2b2c927da0598da3e.previous_frame()">
#         <i class="fa fa-step-backward"></i></button>
#     <button onclick="animb36a6234b0584cd2b2c927da0598da3e.reverse_animation()">
#         <i class="fa fa-play fa-flip-horizontal"></i></button>
#     <button onclick="animb36a6234b0584cd2b2c927da0598da3e.pause_animation()"><i class="fa fa-pause">
#         </i></button>
#     <button onclick="animb36a6234b0584cd2b2c927da0598da3e.play_animation()"><i class="fa fa-play"></i>
#         </button>
#     <button onclick="animb36a6234b0584cd2b2c927da0598da3e.next_frame()"><i class="fa fa-step-forward">
#         </i></button>
#     <button onclick="animb36a6234b0584cd2b2c927da0598da3e.last_frame()"><i class="fa fa-fast-forward">
#         </i></button>
#     <button onclick="animb36a6234b0584cd2b2c927da0598da3e.faster()"><i class="fa fa-plus"></i></button>
#   <form action="#n" name="_anim_loop_selectb36a6234b0584cd2b2c927da0598da3e" class="anim_control">
#     <input type="radio" name="state"
#            value="once" > Once </input>
#     <input type="radio" name="state"
#            value="loop" checked> Loop </input>
#     <input type="radio" name="state"
#            value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgb36a6234b0584cd2b2c927da0598da3e";
#     var slider_id = "_anim_sliderb36a6234b0584cd2b2c927da0598da3e";
#     var loop_select_id = "_anim_loop_selectb36a6234b0584cd2b2c927da0598da3e";
#     var frames = new Array(0);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADl0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uIDIuMi4yLCBo\
# dHRwOi8vbWF0cGxvdGxpYi5vcmcvhp/UCwAAIABJREFUeJzt3X90lOWd//9XSASD9ZMAG344YTUh\
# IQohhu1EsDlVCEYWPQZdUfH4I/7A0MLWlt1Fs0ulek5ZwrEf+zn+wk1lJV23RqVuYsUFcaPuHo4K\
# o8nXYNWmElkYUhqSkNoKCYTr+wedMTETnHvuZO57uJ+PczxL7rnve95cXHvx7nDd80oyxhgBAADP\
# +p//+R/dfPPN+uSTT3TOOec4XU5MPvvsM2VlZen48eNKSUmJeM6ePXv093//93rvvffU0dEhWiDE\
# apTTBQAAgJFz4sSJrz1n3759uuCCCxK2eY7WWWedpRtvvFGbNm1yuhQkOBpoAADOMBdccIE2bNig\
# goICnXPOOTpx4oQOHjyo66+/XhkZGcrKytKjjz4qSdq0aZOWLVumt99+W9/4xjf0ox/9SG+++aYy\
# MzMH3O8nP/mJCgoKlJaWpptuuknHjh0Lv/7KK6+osLBQ6enp+ta3vqUPPvhgwLUPP/xwuJa7775b\
# hw4d0qJFi3TuuefqiiuuUFdXV/j8d955R9/61reUnp6uiy++WG+++Wb4tXnz5umBBx5QcXGxzj33\
# XF155ZU6fPiwJOmyyy6TJKWnp+sb3/iG3n777UHjkpeXp7vvvlszZ84cnoGGdxkAAHBGOf/8883F\
# F19s/vd//9d88cUXpq+vz/zVX/2Veeihh0xPT4/59NNPTVZWltm2bZsxxphnnnnGFBcXh69/4403\
# jM/nG3C/oqIiEwwGTUdHh7nwwgvNxo0bjTHGvP/++yYjI8O888475sSJE2bz5s3m/PPPN8eOHQtf\
# uoRGYBo0aNCgoS6hEZgGDRo0aKhLaASmQYMGDRrqEhqBadCgQYOGuoRGYBo0aNCgoS6hEZgGDRo0\
# aKhLaASmQYMGDRrqEhqBadCgQYOGuoRGYBo0aNCgoS6hEZgGDRo0aKhLaASmQYMGDRrqEoZqn4AG\
# DVLBsizS6TRomoZer4dOp4NerwdFUdU+NQ0aNCgIjcA01C34xJXJZJBOp6HT3Ugq7OzsoKmpCc3N\
# zTAYDByx6XQ6jdg0aGgQaASmoe7AsiwymQwymQxeeukl3HbbbVzURQgsHA4DAKxWKzKZDFiW5YiL\
# oijo9XqN2DRoqHNoBKahbsAwDBdtATeIiP+HD/J/QmgELMsCALcfPrEREiR/NGLToKG2oRGYhpoH\
# wzDIZDKgaRoABAkrFxRFcWSV+3P+3wTktSQVyYdGbBo01CY0AtNQsxBDXASFCKzY6/l/ExQitnQ6\
# jWg0iq6uLo3YNGioEjQC01BzYBgG6XQaDMMAqIy4CColsGL74f9NEI/HsbGxgfb2di1i06ChStAI\
# TENNgGVZTlUohbgI5CKwYvsHCtfYtFSkBg3KQyMwDVWF3MRFoAaBia2xpVKprN9rxKZBgzhoBKah\
# KmBZlqtxXb9+HYODg7Db7bIt2koTWKXgExs/auMTeC6xJRIJWCwWWCwWjdg0aBCAZiWlQVWwLAua\
# ppFKpZBKpbj/Mwwj+8JcjMBYlsUDDzyA4eFhvOMd78DPfvYz3HrrrbIevxwQQuP3pRGyWltbQyAQ\
# QDweRzQaRTgcRjAYRCgUQiwWQyKR4Bq5a4msNWhQC1oEpkEVEKLi916RPzqdjksfioVQH1ixRf2l\
# l17Cf//3f+P69euw2WwAgMuXL1d0PKVTlOSzMRjeuk1JxJZKpeByuXD48GFsb29nkR/fTuvq1av4\
# yEc+gpdffhk+n08jOg0NBS0C06AoiGtGMpnkRA0kDcZPq0lZWHO3zWQyJfe5srKC4eFhjrzqBfyI\
# Ta/XAwBHWAzDIJVKIRaLIRqNIhQKIZFI4MyZM/jiF78I4MZnwzCMRmQaGgIagWlQBMWIKxdSIjBC\
# VPv27cNjjz2GU6dOobe3FzRNY3NzE3fddRdGRkZw8OBBPPnkkwCAf//3f8cf/dEfYXZ2Fn19ffjk\
# Jz+JH//4x9i3bx+33wMHDuDzn/88Tp06hcHBQdx7771IJBLc77///e/jnnvuwdDQEN75znfijTfe\
# yNr28ccf587l7Nmz2Nrawm//9m+jv78fZ86cgd/v514/OzuLd77znRgaGsJtt92GH//4x9xn+N73\
# vhd//dd/jV/5lV9Bf38/fuM3fgM+nw8A8K53vQsAMDQ0hP7+fly8eDEvFTk5OYm77roLY2NjAIBI\
# JIJQKIRgMMilJBOJhEZsGuoSGoFpkBWVEBeBTqcTvXDyI61vfvOb+MY3vgG32w29Xo+zZ8/iwIED\
# mJubw3PPPYcnn3wSL774Iu6++2489thjOH78ODweD/7iL/5CcN/f/va38e1vfxuvv/463njjDfzH\
# f/wHAOC1117Dhz/8YXz0ox/F8vIy3ve+9+HOO+9EMpnktj137hzOnTuHy5cv4/nnn

# %%
plt.close()

# %%
fig, ax = draw_plots(data2d)
plt.show()

# %%
data5d = main(function, 5, function_name=function_string, refinement_level = 7)
# Out:
#  ----------------
# TasmanianSG version: 4.0
# TasmanianSG license: BSD 3-Clause
# Using fixed sparse grid with depth 5
# Classic refinement
#
#  ----------------

# %%
fig, ax = draw_plots(data5d)
plt.show()
