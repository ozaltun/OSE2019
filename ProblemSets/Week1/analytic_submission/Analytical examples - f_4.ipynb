# %%
from helper import *

# %%
function = f_4
function_string = 'f_4'

# %%
data2d = main(function, 2, function_name=function_string, refinement_level = 10)
# Out:
#  ----------------
# TasmanianSG version: 4.0
# TasmanianSG license: BSD 3-Clause
# Using fixed sparse grid with depth 5
# Classic refinement
#
#  ----------------
# helper.py:27: RuntimeWarning: overflow encountered in exp
#   return np.exp(t*(c**2 * (x - w)**2).sum())

# %%
fig, ax = plt.subplots(1, 2, sharey=True, figsize=(10, 5))
fig.tight_layout()

ax[0].axis([-1,1,-1,1])
ax[1].axis([-1,1,-1,1])

print('fig size: {0} DPI, size in inches {1}'.format(
    fig.get_dpi(), fig.get_size_inches()))

x = data2d[0]['aPoints'][:,0]
y = data2d[0]['aPoints'][:,1]

ax[0].scatter(x, y)
ax[1].scatter([],[])

def update(i):
    label = 'refinement {0}'.format(i+1)
    ax[1].scatter(data2d[1][i+1]['aPoints'][:,0], data2d[1][i+1]['aPoints'][:,1],color='blue')
    ax[1].set_title(label)

anim = FuncAnimation(fig, update, frames=np.arange(0, 10), interval=1000)
HTML(anim.to_jshtml())
# Out:
# fig size: 72.0 DPI, size in inches [10.  5.]
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_img3c8fdc4d02e941d3879888d95d5a88e7">
#     <br>
#     <input id="_anim_slider3c8fdc4d02e941d3879888d95d5a88e7" type="range" style="width:350px"
#            name="points" min="0" max="1" step="1" value="0"
#            onchange="anim3c8fdc4d02e941d3879888d95d5a88e7.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="anim3c8fdc4d02e941d3879888d95d5a88e7.slower()"><i class="fa fa-minus"></i></button>
#     <button onclick="anim3c8fdc4d02e941d3879888d95d5a88e7.first_frame()"><i class="fa fa-fast-backward">
#         </i></button>
#     <button onclick="anim3c8fdc4d02e941d3879888d95d5a88e7.previous_frame()">
#         <i class="fa fa-step-backward"></i></button>
#     <button onclick="anim3c8fdc4d02e941d3879888d95d5a88e7.reverse_animation()">
#         <i class="fa fa-play fa-flip-horizontal"></i></button>
#     <button onclick="anim3c8fdc4d02e941d3879888d95d5a88e7.pause_animation()"><i class="fa fa-pause">
#         </i></button>
#     <button onclick="anim3c8fdc4d02e941d3879888d95d5a88e7.play_animation()"><i class="fa fa-play"></i>
#         </button>
#     <button onclick="anim3c8fdc4d02e941d3879888d95d5a88e7.next_frame()"><i class="fa fa-step-forward">
#         </i></button>
#     <button onclick="anim3c8fdc4d02e941d3879888d95d5a88e7.last_frame()"><i class="fa fa-fast-forward">
#         </i></button>
#     <button onclick="anim3c8fdc4d02e941d3879888d95d5a88e7.faster()"><i class="fa fa-plus"></i></button>
#   <form action="#n" name="_anim_loop_select3c8fdc4d02e941d3879888d95d5a88e7" class="anim_control">
#     <input type="radio" name="state"
#            value="once" > Once </input>
#     <input type="radio" name="state"
#            value="loop" checked> Loop </input>
#     <input type="radio" name="state"
#            value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img3c8fdc4d02e941d3879888d95d5a88e7";
#     var slider_id = "_anim_slider3c8fdc4d02e941d3879888d95d5a88e7";
#     var loop_select_id = "_anim_loop_select3c8fdc4d02e941d3879888d95d5a88e7";
#     var frames = new Array(0);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADl0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uIDIuMi4yLCBo\
# dHRwOi8vbWF0cGxvdGxpYi5vcmcvhp/UCwAAIABJREFUeJzt3X9wleWd//9XSASD9ZMAG354wmpC\
# QgRCDNsTwWaqEIwsOgZdkR/jj/gDQ7tsbdldNLtUqjNlCWM/9jOK1U1lJV23RqVuQsUFcSPuDqPC\
# 0eRrsGJTCSwcUjYkIbUVEgjX9w/nHBNzgrnPnZz7PtzPxwwz5j73fZ83F9dcvD1c93klGGOMAACA\
# Z/33f/+3li9frk8++USXXHKJ0+VE5dChQ8rIyNCZM2eUlJQU8Zz9+/fr7/7u7/T++++rra1NtECI\
# 1ginCwAAAMPn7NmzX3vO4cOHdcUVV8Rt8zxYF110kZYsWaLNmzc7XQriHA00AAAXmCuuuEIbN25U\
# LgOGYZB7SWjCpqFRm2gCplGzFBKuSCSC5eVlpFIpJJNJ/Nqv/RpomubtgbndblgsFnR3dyMejyMW\
# i7FfiUQCer2eFTbyVYmwZTIZxGIxdHd3a8KmoVEltBSiRs1BxIimaQBvClc4HIbT6UQ2m8X4+Dg6\
# Ozvxi1/8QlAwdDodm0K02+2w2+28n1MUxQpbKBTCxsYGkskk9Ho9T9Sam5vR1NSUl4pMJBLY2tpC\
# R0cHMpkM72daxKahoQ6agGnUBCTCERKuYDAIp9MJABgfH0d7e3vJxyMCVgiDwYCWlha0tLTwvk9R\
# FBupBQIBrK2tIZVKwWAw8ESNK5C5rwMAWxXJRRM2DQ150QRMo6oUE65AIACn0wmDwYCJiQm0tbWV\
# /bilBKwQBoMBra2taG1t5X0/m80iHo8jGo3C5/MhHA4jFovh8uXL7N4a+TKbzQVTkdlsFul0mvdz\
# Tdg0NMShCZhGVWAYht3junHjBgYHB9k0n9/vx/LyMkwmE6anp/OipHIQK2CFMBqNPGGLx+NYXl7G\
# zMwMG7F5vV6srKwgk8nAaDTyRM1ut8NkMkGn0/GiNq6A5wpbMpmExWKBxWLRhE1DQwBNwDRUhStc\
# NE1Dp9OBoihQFAWv14vl5WVYrVbs378/b99KzLmK/exjH/sY/uu//gtjY2P4/Oc/j49//ON49dVX\
# KzqH0WhEW1tbXnRIijxisRh2d3dZYTOZTHl7bCaTSfD5ra+vo6urC21tbXkRm9Fo5PW+acKm8VZE\
# EzANVWAYJq/3iiy4yWQSV69eRXt7Ow4fPgybzVbx4+cu3qUisPPnz+N///d/cePGDTQ3NwNAReJV\
# 6vFNJhPa29vz9uvS6TQrbNvb24jFYshmszCbzXnCRqI1o/HNy5REbOl0Gm63G3Nzc9jd3WWbsrlp\
# SIPBgGvXruETn/gELl++DJ/PJ2tUqqFRbTQB01AUIeHS6/VgGAbb29twuVygKArj4+PYu3ev6HNw\
# yWazJQVmdXUV+/btY8VLLcxmM8xmMzo6OtjvkRRiNBpFLBbD5uYmYrEY4vE4QqEQ2tvbecJmMBgA\
# gPdfvV7PNnpzm7OTySTOnj2LD33oQ7jzzjuRzWbZaE2L2DTqHc2NXkMRiN1TKpViq

# %%
plt.close()

# %%
fig, ax = draw_plots(data2d)
plt.show()

# %%
data5d = main(function, 5, function_name=function_string, refinement_level = 4)
# Out:
#  ----------------
# TasmanianSG version: 4.0
# TasmanianSG license: BSD 3-Clause
# Using fixed sparse grid with depth 5
# Classic refinement
#
#  ----------------
# helper.py:131: RuntimeWarning: invalid value encountered in subtract
#   fError1 = max(np.fabs(aRes[:,0] - aTres))

# %%
fig, ax = draw_plots(data5d)
plt.show()
